# %%
# !git clone https://github.com/devalab/molgpt.git
# Out:
# Cloning into 'molgpt'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 89 (delta 11), reused 7 (delta 7), pack-reused 72 (from 1)
# Receiving objects: 100% (89/89), 41.04 KiB | 368.00 KiB/s, done.
# Resolving deltas: 100% (43/43), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/BenevolentAI/guacamol.git
# !git clone https://github.com/molecularsets/moses.git
# Out:
# Cloning into 'moses'...
# remote: Enumerating objects: 1957, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 1957 (delta 0), reused 2 (delta 0), pack-reused 1953 (from 1)
# Receiving objects: 100% (1957/1957), 164.05 MiB | 30.25 MiB/s, done.
# Resolving deltas: 100% (1068/1068), done.
# ...
# You can inspect what was checked out with 'git status'
# and retry with 'git restore --source=HEAD :/'
#
#
# Exiting because of "interrupt" signal.
# ^C

# %%
# %cd moses
# Out:
# /content/molgpt/moses

# %%
# !python setup.py install

# %%
# %cd ..
# Out:
# /content/molgpt

# %%
# %cd molgpt
# Out:
# /content/molgpt

# %%
# !pip install guacamol

# %%
# !pwd
# Out:
# /content

# %%
# !pip uninstall pandas -y
# !pip install pandas==1.5.3

# %%
# !wandb login

# %%
# !chmod +x train_guacamol.sh

# %%
# !./train_guacamol.sh

# %%
# !python generate/generate.py --model_weight /content/molgpt/gua_tpsa_logp_sas.pt --props tpsa logp sas --data_name guacamol2 --csv_name gua_tpsa_temp1 --gen_size 1000 --batch_size 512 --vocab_size 94 --block_size 100
# Out:
# Streaming output truncated to the last 5000 lines.
# [18:19:03] DEPRECATION WARNING: please use MorganGenerator
# [18:19:03] DEPRECATION WARNING: please use MorganGenerator
# [18:19:03] DEPRECATION WARNING: please use MorganGenerator
# [18:19:03] DEPRECATION WARNING: please use MorganGenerator
# [18:19:03] DEPRECATION WARNING: please use MorganGenerator
# [18:19:03] DEPRECATION WARNING: please use MorganGenerator
# [18:19:03] DEPRECATION WARNING: please use MorganGenerator
# [18:19:03] DEPRECATION WARNING: please use MorganGenerator
# [18:19:03] DEPRECATION WARNING: please use MorganGenerator
# [18:19:03] DEPRECATION WARNING: please use MorganGenerator
# [18:19:03] DEPRECATION WARNING: please use MorganGenerator
# [18:19:03] DEPRECATION WARNING: please use MorganGenerator
# [18:19:03] DEPRECATION WARNING: please use MorganGenerator
# [18:19:03] DEPRECATION WARNING: please use MorganGenerator
# [18:19:03] DEPRECATION WARNING: please use MorganGenerator
# ...

# %%
# !python generate/generate.py --model_weight /content/molgpt/guacamol_nocond.pt --data_name guacamol2 --csv_name gua_tpsa_temp1 --gen_size 10000 --batch_size 512 --vocab_size 94 --block_size 100
# Out:
# /usr/local/lib/python3.10/dist-packages/molsets-1.0-py3.10.egg/moses/metrics/utils.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   _mcf.append(_pains, sort=True)['smarts'].values]
# ...

# %%
# !python generate/generate.py --model_weight /content/drive/MyDrive/molgpt/cond_gpt/weights/unconditional_guacamol.pt --data_name guacamol2 --csv_name gua_uncond --gen_size 10000 --batch_size 512 --vocab_size 94 --block_size 200
# Out:
# /usr/local/lib/python3.10/dist-packages/molsets-1.0-py3.10.egg/moses/metrics/utils.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   _mcf.append(_pains, sort=True)['smarts'].values]
# ...

# %%
# !python generate/generate.py --model_weight /content/molgpt/moses_nocond_4layer.pt --data_name moses2 --csv_name moses_uncond --gen_size 10000 --batch_size 512
# Out:
# /usr/local/lib/python3.10/dist-packages/molsets-1.0-py3.10.egg/moses/metrics/utils.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   _mcf.append(_pains, sort=True)['smarts'].values]
# Traceback (most recent call last):
#   File "/content/molgpt/generate/generate.py", line 60, in <module>
#     data = pd.read_csv(args.data_name + '.csv')
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 211, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py", line 331, in wrapper
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py", line 950, in read_csv
#     return _read(filepath_or_buffer, kwds)
#   File "/usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py", line 611, in _read
#     return parser.read(nrows)
# ...
